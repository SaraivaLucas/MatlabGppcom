# %% [markdown]
# # Hands-on 02: Python Basics
#
# ### Autor: João Marcos Costa
# #### Data : 19/04/2017 (última atualização)

# %% [markdown]
# # 1. Objetivos
# - Expor as funcionalidades de Python
# - Apresentar as vantagens e desvantagens da linguagem
# - Apresentar a Spyder (interface de desenvolvimento)
# - Explicar o processo de depuração (_debug_) na Spyder

# %% [markdown]
# # 2. Python: o que é, vantagens e desvantagens
# Python é uma linguagem de programação de alto nível, interpretada (C++, por sua vez, é compilada) , lançada em 1991 por [Guido van Rossum](https://pt.wikipedia.org/wiki/Guido_van_Rossum). É conhecida por ser _open source_, de fácil implementação e fácil aprendizado, além de ser multiparadigma: abrange a programação orientada a objetos, programação funcional e imperativa. (Para saber mais sobre paradigmas de programação, clique [aqui](https://fit.faccat.br/~guto/artigos/Artigo_Paradigmas_de_Programacao.pdf).
#
# ## Vantagens
# - Suporta mútliplos sistemas e plataformas
# - Códigos fáceis de implementar e entender
# - Orientação a objetos
# - Tipagem dinâmica: pode ser visto como desvantagem para alguns, já que não se determina o tipo de cada variável, porém economiza tempo e esforço por evitar erros de atribuição que dificultam a execução do código.
# - Ampla biblioteca padrão
# - Possui _frameworks_(conceito semelhante ao de "biblioteca"), que serão expostos adiante.
#
# ## Desvantagens
# - Não é uma linguagem muito boa para desenvolvimento _mobile_
# - O gerenciamento de memória não é tão eficiente como o de C++, por exemplo
# - Por vezes é considerada lenta
# - Não é aconselhável para projetos que requisitem muita memória
# - É quase impossível desenolver um jogo com alta qualidade de gráficos 3D em Python

# %% [markdown]
# ## Frameworks interessantes
#
# Frameworks podem ser vistos como um conjunto de ferramentas que lidam com detalhes de baixo nível e permite que o desenvolvedor poupe seu tempo utilizando apenas os recursos de alto nível. Embora essa pareça com a definição de bibliotecas, uma maneira fácil de diferenciar os dois conceitos é: você coloca bibliotecas em seus códigos e seus códigos em frameworks. Em Python, temos:
# - Django: The Web Framework for perfectionists with deadlines
# <img src="./handsOn2_python_figs/django.jpg" height=200'' width = 400'' />
# Amplamente utilizado para desenvolver aplicações Web robustas com facilidade e rapidez. Sites famosos que utilizaram Django para seu desenvolvimento são: YouTube, Dropbox, Quora, Google, [etc](https://www.shuup.com/en/blog/25-of-the-most-popular-python-and-django-websites/).
# - PyQt: desenvolvimento de aplicações com interfaces gráficas (GUI).
# <img src="./handsOn2_python_figs/pyqt.jpg" />
# - Kivy: desenvolvimento de interfaces gráficas, abrangendo mais plataformas que o PyQt
# <img src="./handsOn2_python_figs/kivy.png" />

# %% [markdown]
# ## Bibliotecas mais utilizadas
# - Matplotlib: plotagem de gráficos 2D com interatividade e diversos formatos.
# <img src="./handsOn2_python_figs/matplotlib.png" />
# - Numpy: criação de arrays N-dimensionais, ferramentas algébricas, números aleatórios e Transformada de Fourier.
# <img src="./handsOn2_python_figs/numpy.jpg" />
# - SciPy: biblioteca maior que engloba ferramentas importantes para cientistas, matemáticos e engenheiros. Numpy e Matplotlib estão inclusas na SciPy. Veja mais no site oficial da SciPy: https://www.scipy.org/

# %% [markdown]
# # Trabalhando na Spyder
# <img src="./handsOn2_python_figs/spyder.png" height=300'' width=400'' />
#
# A Spyder é uma IDE utilizada para programação em Python, e já vem inclusa no pacote Anaconda. Sua maior vantagem é ser completa: possui todas as ferramentas que a programação normalmente requer. Entre essas, podemos citar:
# - Depuração (_debug_)
# - Criação e edição de scripts
# - Configuração de preferências
# - Personalização do ambiente de edição
# - Console
# - Histórico de comandos

# %% [markdown]
# ## Workspace
# A interface da IDE é montada de tal forma que possa exibir todas as ferramentas citadas acima, como mostrado abaixo:
# <img src="./handsOn2_python_figs/spyder2.png"/>

# %% [markdown]
# 1. Ambiente de edição do script. É uma alternativa a qualquer editor de texto, e seu estilo (cor, highlighting, e background) pode ser alterado nas preferências (item 8).
# 2. Nesta tela, podem ser exibidos os consoles Python, IPython e o Log do Histórico. No console Python, se executa uma linha por vez, enquanto no ambiente de edição se executa todo o script. No console IPython, que não será utilizado nessa série de Hands-ons, o usuário pode programar interativamente, tal como fazemos no Jupyter (lembrando que IPython é o que hoje se conhece por Jupyter, a grosso modo). No histórico, estão relatados todos os comandos executados pelo usuário.
# 3. Nesta janela menor, podemos ver quais variáveis já foram alocadas, seus nomes, tamanhos e valores, bem como os arquivos do sistema. Também é possível obter ajuda (explicação) sobre qualquer objeto do console ou do editor. Para isso, basta selecioná-lo e usar Ctrl-I que a documentação acerca do elemento será exibida na tela.
# 4. Menu de arquivos.
# 5. Menu de execução.
# 6. Menu de depuração.
# 7. Tela cheia (F11).
# 8. Menu de preferências (Ctrl+Alt+Shift+P)
# 9. Menu de navegação para o diretório de trabalho.

# %% [markdown]
# # Prática 1
# Nesta primeira prática, iremos executar um script que implementa a modulação em amplitude. Siga os passos como se pede: <br>
# **Passo 1: ** Crie uma novo arquivo .py com o comando Ctrl-N, ou clicando no primeiro ícone do Menu de arquivos. <br>
# **Passo 2: ** Copie e cole o código abaixo no ambiente de edição:

# %%
import numpy as np
Am = 1.0
fm = 60
ka=1.0
u =ka*Am
Ac = 2.0
t = np.linspace(0,1000,1000)
fc = 70
m_t = Am*np.cos(2*np.pi*fm*t)
s_t = Ac*(1+u*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*t*fc)
from matplotlib import pyplot as plt
plt.plot(t,s_t)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ** Passo 3:** Mude a cor de fundo do ambiente de edição clicando no menu de preferências. <img src="./handsOn2_python_figs/spyder3.png"/>

# %% [markdown]
# **Passo 4:** Ao executar o código, perceba se o gráfico será exibido numa janela separada (interativa) ou no próprio console. Para exibir interativamente, **acesse as Preferências > Console IPython > Saída Gráfica. ** Mude de "Em linha" para "Automático. <br>

# %% [markdown]
# # Prática 2
# Nessa prática, iremos plotar um mapa de cores (_colormap_) de duas maneiras: utilizando um _loop_ e matrizes. Por fim, compararemos qual dos dois métodos tomou menos tempo para ser executado. <br>
#
# Vamos escrever dois códigos para criação de um mapa de cobertura de dois roteadores sem fio. A ideia é calcular a potência recebida em dBm para pontos equidistantes de 5 em 5 metros em uma área de cobertura de 200 por 200 m. A seguintes especificações devem ser obedecidas:
#
# 1. Os roteadores devem ser posicionados no meio do grid em relação a abscissa. Em relação ao eixo das ordenadas, o primeiro e segundo roteador deve ficar a 20% e a 80% da dimensão vertical da área de cobertura, respectivamente;
# 2. A potência de transmissão do roteador deve ser $P_T$ = 1 W;
# 3. Considere somente perda de percurso como manifestação de canal. Assim, a potência recebida ($P_R$) pode ser calculada como $P_R = P_T/d^4$, sendo $d$ a distância entre o roteador e o ponto de recepção.
#
# A figura a seguir ilustra o sistema.
# <img src="./handsOn2_matlab_figs/slide30.png" />
# Vamos escrever, primeiramente, o código sem laço for:

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 20:08:53 2017

@author: joaomarcos
"""
dPasso = 5
dDim = 200
import time
start_time = time.clock()
import numpy as np
x= np.arange(dPasso,dDim-dPasso,dPasso)
y=np.arange(dPasso,dDim-dPasso,dPasso)
X,Y = np.meshgrid(x,y)

pbs0 = X + 1j*Y - (dDim/2 + 0.8*dDim*1j)
pbs1 = X + 1j*Y - (dDim/2 + 0.2*dDim*1j)

pl0 = 10*np.log10(1/(np.absolute(pbs0)**4)/0.001)
pl1 = 10*np.log10(1/(np.absolute(pbs1)**4)/0.001)

stop_time = time.clock()
tempo_de_execucao = stop_time - start_time
from matplotlib import pyplot as plt
#plt.matshow(pbs0)
#plt.matshow(pbs1)
plt.matshow(pl0)
plt.grid()
plt.colorbar()
plt.title("Sistema sem laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
plt.matshow(pl1)
plt.grid()
plt.colorbar()
plt.title("Sistema sem laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
plt.matshow(pl0+pl1)
plt.grid()
plt.colorbar()
plt.title("Sistema sem laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
# Out:
# /home/labsim/anaconda3/lib/python3.4/site-packages/ipykernel/__main__.py:20: RuntimeWarning: divide by zero encountered in true_divide
# /home/labsim/anaconda3/lib/python3.4/site-packages/ipykernel/__main__.py:21: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# Agora, escrevendo  o sitema com laço for:

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 17:54:13 2017

@author: joaomarcos
"""
#exemplo com laço for

import time
start_time = time.clock()
# %matplotlib inline
dPasso = 5;
dDim = 200;
nl = (dDim-2*dPasso)/dPasso + 1;
import numpy as np
NL = int(nl) #nl não é do tipo inteiro
px = np.ndarray([NL,NL])
py = np.ndarray([NL,NL])
#Matriz com posição de cada ponto do grid 
#(posição relativa ao canto inferior direito)

for i in range(NL):
    for j in range(NL):
        px[i,j] = dPasso + j*dPasso
        py[j,i] = px[i,j]

#Matrizes de posição e potência recebida
pbs0 = np.ndarray([NL,NL], dtype=complex)
pbs1 = np.ndarray([NL,NL], dtype=complex)
pl0  = np.ndarray([NL,NL])
pl1  = np.ndarray([NL,NL])
plf  = np.ndarray([NL,NL])

for i in range(NL):
    for j in range(NL):
#Matrizes com posição de cada ponto do grid relativa 
#a cadaroteador
        pbs0[i,j] = px[i,j]+ 1j*py[i,j] - ( dDim/2 + 0.8*dDim*1j);
        print()
        pbs1[i,j] = px[i,j]+ 1j*py[i,j] - ( dDim/2 + 0.2*dDim*1j);
#cálculo da potência recebida em cada ponto do grid
# recebida de cada roteador
        
        pl0[i,j]=  10*np.log10(1/(np.absolute(pbs0[i,j])**4)/0.001)
        pl1[i,j]=  10*np.log10(1/(np.absolute(pbs1[i,j])**4)/0.001)
#cálculo da melhor potência em cada ponto do grid
        plf[i,j] = max(pl0[i,j],pl1[i,j])               

from matplotlib import pyplot as plt
stop_time = time.clock()
tempo_de_execucao = stop_time - start_time
from matplotlib import pyplot as plt
#plt.matshow(pbs0)
#plt.matshow(pbs1)
plt.matshow(pl0)
plt.grid()
plt.colorbar()
plt.title("Sistema com laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
plt.matshow(pl1)
plt.grid()
plt.colorbar()
plt.title("Sistema com laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
plt.matshow(pl0+pl1)
plt.grid()
plt.colorbar()
plt.title("Sistema com laço: "+ str(tempo_de_execucao)+ " segundos",y=1.1)
# Out:
# /home/labsim/anaconda3/lib/python3.4/site-packages/ipykernel/__main__.py:46: RuntimeWarning: divide by zero encountered in double_scalars
# /home/labsim/anaconda3/lib/python3.4/site-packages/ipykernel/__main__.py:45: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# Ao fim desse Hands-on, espera-se que o usuário tenha entendido o básico sobre a linguagem Python, os recursos da Spyder e como programar nela.
